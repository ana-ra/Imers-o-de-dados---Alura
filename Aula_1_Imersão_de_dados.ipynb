# %% [markdown]
# <a href="https://colab.research.google.com/github/ana-ra/Imers-o-de-dados---Alura/blob/main/Aula_1_Imers%C3%A3o_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sn
import numpy as np
import matplotlib.pyplot as plt

url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"
dados = pd.read_csv(url_dados, compression ='zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados["tratamento"]

#isso e uma serie
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
#me retornou os valores unicos da coluna, quais sao as categorias da coluna
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %% [markdown]
# ##Desafio 01: investigar por que a classe tratamento é tão desbalanceada?
# ## Desafio 02: Plotar as 5 ultimas linhas da tabela.
# ## Desafio 03: Proporcao das classes tratamento?
# ## Desafio 04 : Quantos tipos de drogas foram investigadas?
# ## Desafio 05: Procurar na documentacao o metodo query(pandas).
# ##Desafio 06: Colocar legenda do grafico e deixar mais agradavel visivelmente.
# ## Desafio 07: Renomear as colunas tirando o hifen.
# ## Desafio 08: Resumo do que voce conseguiu fazer.

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
#compartivo entre as proporcoes dentro de tratamento 
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['droga'].value_counts(normalize = True)
# Out:
# cacb2b860    0.078357
# 87d714366    0.030150
# 9f80f3f77    0.010330
# 8b87a7a83    0.008524
# 5628cb3ee    0.008482
#                ...
# 32dccc366    0.000042
# 0e6ee26ff    0.000042
# cf21e6ee0    0.000042
# 6fbceecd4    0.000042
# 809527b9d    0.000042
# Name: droga, Length: 3289, dtype: float64

# %%
dados['tempo'].value_counts(normalize = True)
# Out:
# 48    0.346435
# 72    0.327202
# 24    0.326363
# Name: tempo, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie() #qual sera que tem a maior proporcao aqui?

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados['g-0'] > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
dados_filtrados = dados[dados['g-0'] >0 ]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# Breve analise dos dados

# %% [markdown]
# Tramento

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
ax = dados['tratamento'].value_counts(normalize=True).plot.bar(title="Tipos de tratamento", rot=0, ylabel='Proporção', color ='green')
for p in ax.patches:
  (int(p.get_height()*dados.shape[0])), (p.get_x()+0.18, p.get_height()+0.01)

# %% [markdown]
# Tempo:

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
ax = dados['tempo'].value_counts(normalize=True).plot.bar(title="Tempo para observação", rot=0, ylabel ='Proporção', xlabel='Tempo(horas)', color = 'green')
for p in ax.patches:
  ax.annotate(str(int(p.get_height()*dados.shape[0])), (p.get_x()+0.18, p.get_height()+0.005))

# %% [markdown]
# Dose

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
ax = dados['dose'].value_counts(normalize=True).plot.bar(title="Doses", rot=0, ylabel='Proporção', xlabel='Tipo de dose', color='green')
for p in ax.patches:
    ax.annotate(str(int(p.get_height()*dados.shape[0])), (p.get_x()+0.18, p.get_height()+0.005))

# %% [markdown]
# Droga

# %%
drogas = dados['droga'].unique()
n_drogas = drogas.shape[0]
drogas
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
#Foram investigadas 3289 drogas.

# %%
drogas_freq = dados['droga'].value_counts().sort_values(ascending=False)
drogas_freq[:20]
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
# d08af5d4b     196
# 292ab2c28     194
# d50f18348     186
# d1b47f29d     178
# 67c879e79      19
# d488d031d      18
# 52d1e6f43      18
# 83a9ea167      18
# a7c2673c1      14
# 5d9bb0ebe      14
# 30aa2f709      14
# 11f66c124      14
# 6b8b675cc      14
# 1a52478dc      14
# 0b1ed98a0      13
# Name: droga, dtype: int64

# %% [markdown]
# Resolvendo o desafio 1
#
# ```
# # Isto está formatado como código
# ```

# %% [markdown]
# Como observamos anteriormente apenas 1866 experimentos tem a classe com_controle para tentar descobrir o motivo vamos tomar como ponto de partida uma analise da coluna 'droga' da base de dados.
#
# Primeiro vamos contar a frequencia de cada droga com o groupby para ver a distribuicao dos experimentos em cada droga.
#
# Double-click to edit

# %%
droga_group_count_asc = dados.groupby('droga')['id'].count().reset_index(name='Count').sort_values(by='Count',ascending=True)
droga_group_count = dados.groupby('droga')['id'].count().reset_index(name='Count').sort_values(by='Count',ascending=False)
droga_group_count.head()
# Out:
#           droga  Count
# 2544  cacb2b860   1866
# 1664  87d714366    718
# 1965  9f80f3f77    246
# 1705  8b87a7a83    203
# 1051  5628cb3ee    202

# %% [markdown]
# Podemos observar que  no histograma gerado com as 30 primeiras amostras de drogas. Entretando apenas uma pequena porção das drogas tem um número relativament grande de experimentos. Podemos também observar na Função Distribuição Acumulada (CDF) que essas amostras dominantes compõem mais ou menos cerca de 20% dos experimentos e uma delas se destaca por compor quase 8% dos experimentos.

# %%
fig, axs = plt.subplots(1,2, figsize=(15,6))
axs[0].bar(droga_group_count[:30]['droga'], droga_group_count[:30]['Count']/dados.shape[0], color='green')
axs[0].set_xticks([])
axs[0].set_title("Histograma")
axs[0].set_ylabel("Probabilidade")
axs[1].stem(droga_group_count_asc['Count'].cumsum()/sum(droga_group_count_asc['Count']))
axs[1].grid(True)
axs[1].set_title("Função de distribuição cumulativa")
axs[1].set_ylabel("Probabilidade acumulada")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# Text(0, 0.5, 'Probabilidade acumulada')

# %% [markdown]
# Após analisar drogas podemos aferir a frequência de ocorrência de um tratamento com uma droga. Já é possível ver que um grande número de drogas não possui nenhum   grupo de controle.

# %%
group_droga_tratamento = dados.groupby(['droga', 'tratamento'])['id'].count()
group_droga_tratamento
# Out:
# droga      tratamento
# 00199ff52  com_droga      6
# 00251fc41  com_droga      6
# 00321ea80  com_droga     12
# 0034c0847  com_droga      6
# 0060e686f  com_droga      6
#                          ..
# ff9565933  com_droga      6
# ffd66e220  com_droga      6
# ffe357f8f  com_droga      1
# ffed8e1c9  com_droga      6
# fff7d208d  com_droga      6
# Name: id, Length: 3289, dtype: int64

# %%
group_droga_tratamento.filter(like='com_controle', axis=0)
# Out:
# droga      tratamento
# cacb2b860  com_controle    1866
# Name: id, dtype: int64

# %% [markdown]
# Resolvendo o desafio 2
# (Plotando os 5 últimos dados da tabela)

# %%
dados.tail(5)
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# Resolvendo o desafio 3

# %%
#compartivo entre as proporcoes dentro de tratamento 
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# Resolvendo o desafio 4

# %%
dados['droga'].value_counts()
#Vemos então que existem 3289 drogas diferentes
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 32dccc366       1
# 0e6ee26ff       1
# cf21e6ee0       1
# 6fbceecd4       1
# 809527b9d       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# Resolvendo o desafio 5

# %%
# ?pd.DataFrame.query

# %% [markdown]
# Resolvendo o desafio 6

# %%
dg = dados['tempo'].value_counts()

dg.plot.bar(title ='Grafico da frequência pelo tempo', color = 'green', xlabel ='Horas', ylabel = 'Culturas')

# %% [markdown]
# Resolvendo o desafio 7

# %%
dados.rename(lambda x: x.replace('-', ''), axis=1, inplace=True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Resolvendo o desafio 8

# %% [markdown]
# O desbalanceamento do atributo tratamento se deve ao fato de que apenas uma droga recebeu o tratamento com controle;
#
# Apenas um pequeno número de drogas representa um número grande dos experimentos, sendo 9 delas as mais representativas e 1 dessas é de controle;
#
# A frequência da ocorrência das doses e dos tempos de observação nos experimentos são praticamente balanceadas;
#
# Foram testadas 3289 drogas, sendo 1 delas de controle.
